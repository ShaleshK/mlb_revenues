# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem
import warnings
import csv

# %%
teams_df = pd.read_csv("MLBTeamRevenues.csv")
teams_df.head()
# Out:
#    Year                 Tm       Lg   W    L  Finish         Playoffs  \
# 0  2019  Baltimore Orioles  AL East  54  108       5              NaN
# 1  2018  Baltimore Orioles  AL East  47  115       5              NaN
# 2  2017  Baltimore Orioles  AL East  75   87       5              NaN
# 3  2016  Baltimore Orioles  AL East  89   73       2  Lost ALWC (1-0)
# 4  2015  Baltimore Orioles  AL East  81   81       3              NaN
#
#   Attendance Attend/G        Rank   Est. Payroll  PPF  BPF  \
# 0  1,307,807   16,146  14th of 15   $82,696,100   102   99
# 1  1,564,192   19,311  14th of 15  $141,555,833   100   98
# 2  2,028,424   25,042  12th of 15  $161,621,633    99   97
# 3  2,172,344   26,819  10th of 15  $153,744,833   102  102
# 4  2,281,202   29,246   8th of 15  $112,989,833   102  102
#
#                        Stadium  Revenue  Operating Income  Net Income
# 0  Oriole Park at Camden Yards      NaN               NaN         NaN
# ...

# %%
team_revenue_year = teams_df.pivot(index='Tm',columns='Year')['Revenue']
team_revenue_year.head()
# Out:
# Year                  1998  1999  2000   2001   2002   2003   2004   2005  \
# Tm
# Arizona Diamondbacks   NaN   NaN   NaN  127.0  122.0  126.0  136.0  145.0
# Arizona Diamondbacks   NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN
# Atlanta Braves         NaN   NaN   NaN  160.0  163.0  156.0  162.0  172.0
# Baltimore Orioles      NaN   NaN   NaN  133.0  129.0  129.0  148.0  156.0
# Boston Red Sox         NaN   NaN   NaN  152.0  171.0  190.0  201.0  206.0
#
# Year                   2006   2007  ...   2010   2011   2012   2013   2014  \
# Tm                                  ...
# Arizona Diamondbacks  154.0  165.0  ...  180.0  186.0  195.0  192.0  211.0
# Arizona Diamondbacks    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
# Atlanta Braves        183.0  199.0  ...  201.0  203.0  225.0  253.0  267.0
# Baltimore Orioles     158.0  166.0  ...  175.0  179.0  206.0  198.0  245.0
# Boston Red Sox        234.0  263.0  ...  272.0  310.0  336.0  357.0  370.0
#
# ...

# %%
#bar charts for revenues, payroll, wins, and operating income per team over 2002-2018
revenue = []
payroll = []
wins = []
op_inc = []

for t in teams:
    df_team = teams_df[teams_df.Tm == t]
    revenue.append(df_team['Revenue'])
    payroll.append(df_team['Est. Payroll'])
    wins.append(df_team['W'])
    op_inc.append(df_team['Operating Income'])
    fig,ax = plt.subplots()
    for y in years:
        ax.bar(revenue, years, color='r', alpha=0.5, align="center")
        plt.ylabel("Revenue in $Millions")
        plt.xlabel("Year")
        plt.title("A Team's Revenue from 2002 - 2018")
        for i, v in enumerate(diff_per_game):
            ax.text(v, i + .25, str(v), color='blue', fontweight='bold')
        plt.show()
        # tick_locations = [value for value in x]
        # plt.xticks(tick_locations, x)
        #y = [34, 34, 83, 63, 55, 60, 30, 66, 62, 83, 50]
        #x = array([8673, 8342, 9772, 9847, 8593, 8634, 9931, 9885, 9925, 9823, 8586], dtype=int64)
        plt.savefig("DomTeamsGoalDiff.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-ddc4f4713c04> in <module>
#      13     fig,ax = plt.subplots()
#      14     for y in years:
# ---> 15         ax.bar(revenue, years, color='r', alpha=0.5, align="center")
#      16         plt.ylabel("Revenue in $Millions")
#      17         plt.xlabel("Year")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in bar(self, *args, **kwargs)
#    2231         x, height, width, y, linewidth = np.broadcast_arrays(
# ...

# %%
#bar charts for revenues, payroll, wins, and operating income per year comparing all teams

# %%
#bar charts for cumulative revenues, payroll, wins, and operating income per year for all teams
